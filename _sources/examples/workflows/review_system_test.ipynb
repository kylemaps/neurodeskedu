# %% [markdown]
# # Review System Test Notebook
#
# **Author:** NeurodeskEDU Test
#
# This is a dummy notebook used to test the NeurodeskEDU peer review badge system.
# It intentionally does NOT have an `nd_review_id` in its metadata so that the
# `detect-new-notebooks` workflow can find it and auto-assign one.

# %% [markdown]
# ## Learning Objectives
#
# - Verify the review badge system works end-to-end
# - Test automated UUID generation
# - Test reviewer checklist posting
# - Test SHA recording on review acceptance

# %%
# A simple test cell
print("Hello from the review system test notebook!")
print("If you see a review badge above, the system is working.")

# %%
# Some basic computation to verify the notebook runs
import math

result = math.sqrt(144)
print(f"The square root of 144 is {result}")
print(f"Pi is approximately {math.pi:.6f}")

# %% [markdown]
# ## Summary
#
# This notebook exists solely for testing the review workflow.
# It can be safely deleted after testing is complete.
#
# *Last tested: 2026-02-23*
